# %% [markdown]
# #Welcome to Databricks Learning
# Let us learn this efficiently!!! To get a better job opportunity in Databricks
#
#    ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQl6VdPUFlygcYJiE8ez4fyn5_HrCcjrK0g9g&s)

# %% [markdown]
# ## We are going to start with python!!!

# %% [markdown]
# ### Variables is the first topic to start with in Python

# %%
# %run "/Workspace/Repos/Github/databricks-learning/01_Sanity_check"

# %%
# %python 
a=10
b=20
c=a+b
print(f'The value of C is: {c}')

# %%
dbutils.notebook.exit(0)

# %%
# %sh ls /Workspace/Repos/Github/databricks-learning

# %% [markdown]
# **We are going to use Databricks Unity Catalog
# to create tables and files under the volume (Catalog/Schema/volume/folder/files)**

# %%
# %sql
CREATE VOLUME IF NOT EXISTS Workspace.default.volume1;

# %% [markdown]
# ### Upload some sample data in Catalog> workspace > default > volume1, How to run a DBFS (Hadoop)

# %%
# %fs ls "/Volumes/workspace/default/volume1"

# %% [markdown]
# ### Copying file using dbutils

# %%
dbutils.fs.cp(
    "dbfs:/Volumes/workspace/default/volume1/EmpDept.xlsx","/Volumes/workspace/default/mydrive/Empl2.xlsx"
)

# %% [markdown]
# ### Copying file from one volume to another using FS command

# %%
# %fs cp "dbfs:/Volumes/workspace/default/volume1/EmpDept.xlsx" "/Volumes/workspace/default/mydrive/Empl.xlsx"

# %%
# %sql
Create table if not exists cities(id int, city string );
insert into cities values(1,'Chennai'),(2,'Mumbai'),(3,'Bangalore');
select *from cities;

# %%
# %sql
update cities set city='New Delhi' where id=2;

# %%
# %sql
Select *from cities order by id;

# %%
# %sql
show create table default.cities;

# %%
def sqrt(a):
    return a*a

# %%
print(f'Square root function call {sqrt(10)}')
print('Square root function call', sqrt(100))

# %%
# %python
df1=spark.read.format("excel").option("header", "true").load("/Volumes/workspace/default/volume1/EmpDept.xlsx")
display(df1)

# %%
# %python
df1=spark.read.format("excel").option("header", "True").load("/Volumes/workspace/default/volume1/EmpDept.xlsx")
df2=df1.repartition(4)
display(df2)

# %%
# %python
df2.write.saveAsTable("Employee_details")

# %%
spark.read.table("Employee_details").show(2)

# %% [markdown]
# ### How to intsall additional libraries in this current python interpreter using %pip magic command

# %%
# %python
# %pip install pandas

# %%
import pandas as pd
print(pd.__version__)
